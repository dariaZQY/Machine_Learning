# %%
import numpy as np
import pandas as pd
import pylab as pl
from sklearn import datasets
iris = datasets.load_iris()

# %%
iris.data.shape
# 150 samples, 4 features
# Out:
# (150, 4)

# %%
iris.target.shape
# Out:
# (150,)

# %%
# 3 types of species: 0,1,2
np.unique(iris.target)
# Out:
# array([0, 1, 2])

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB 
from sklearn.ensemble import RandomForestClassifier
clf1=KNeighborsClassifier(n_neighbors=15)
clf2=SVC(kernel='rbf',probability=True)
clf3=RandomForestClassifier(random_state=1)
clf4=GaussianNB()

# %%
x=iris.data[:,:2]  # we only take the first two features.
y=iris.target

# %%
clf1.fit(x,y)
clf2.fit(x,y)
clf3.fit(x,y)
clf4.fit(x,y)
# Out:
# GaussianNB(priors=None)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))
f,axarr= plt.subplots(2, 2, sharex='col',sharey='row',figsize=(8, 6))

# %%
for idx,clf,tt in zip(product([0, 1], [0, 1]),[clf1, clf2, clf3, clf4],['KNN(K=15)', 'SVC','Random Forest', 'GaussianNB']):
    pred=clf.predict(np.c_[xx.ravel(), yy.ravel()])
    pred=pred.reshape(xx.shape)
    axarr[idx[0], idx[1]].contourf(xx,yy,pred,alpha=0.4)
    axarr[idx[0], idx[1]].scatter(X[:,0], X[:,1], c=y,s=20, edgecolor='k')
    axarr[idx[0], idx[1]].set_title(tt)
plt.show()
